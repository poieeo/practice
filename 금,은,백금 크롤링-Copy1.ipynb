# %%
#금값 크롤링하기 
import matplotlib.pyplot as plt
import time
from selenium import webdriver
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.chrome.service import Service
from webdriver_manager.chrome import ChromeDriverManager
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.common.by import By
from bs4 import BeautifulSoup as bs
import pandas as pd

plt.rcParams['font.family'] = 'Malgun Gothic'
# 유니코드에서  음수 부호설정
plt.rc('axes', unicode_minus=False)


options=Options()
options.add_experimental_option('detach',True) #화면이 꺼지지 않고 유지
options.add_argument('--start-maximized') # 화면을 최대화
service=Service(ChromeDriverManager().install()) #크롬드라이버 자동 설치

driver=webdriver.Chrome(service=service, options=options)

sear=['gold','silver','platinum']

tot9=[]
for i in sear:
    url=f'https://www.koreagoldx.co.kr/main/html.php?agencyCode=&htmid=goods/{i}_list.html'
    time.sleep(2)
    driver.get(url)
    time.sleep(3)

    res1=[]
    for i in range(6):                                              
        html=driver.page_source             #페이지정보 받기 ex)처음 나오는 1페이지정보받기 
        res1.append(bs(html,'html.parser'))   #res에 그 정보 받고 담기
        driver.find_element(By.XPATH,'//*[@id="example-table"]/div[3]/span/button[3]').click() #페이지를 클릭하기
        time.sleep(2)                  #다시돌아온다면 2번째 페이지 검색해서 받게됨 
    tot9.append(res1)

# sear=['gold','silver','platinum']
# for i in sear:
#     url=f'https://www.koreagoldx.co.kr/main/html.php?agencyCode=&htmid=goods/{i}_list.html'
#     print(url)

# %%
#첫번쨰방법 리스트와 enu활용하기 
sear=['gold','silver','platinum']

last_res={}
for idx,t in enumerate(tot9):
    tmp1=[]
    for j in t:
        tmp3=[]
        for i in j.find_all('div','tabulator-row'):
            tmp2=[]
            for k in i:
                k.find_all('div','tabulator-cell')
                tmp2.append(k.text)
            tmp3.append(tmp2)
        tmp1.append(pd.DataFrame(tmp3))
    last_res[idx]=tmp1

# %%
#----2번쨰방법 딕트와 zip활용하기 
sear=['gold','silver','platinum']

last_res={}
for s,t in zip(sear,tot9):
    tmp1=[]
    for j in t:
        tmp3=[]
        for i in j.find_all('div','tabulator-row'):
            tmp2=[]
            for k in i:
                k.find_all('div','tabulator-cell')
                tmp2.append(k.text)
            tmp3.append(tmp2)
        tmp1.append(pd.DataFrame(tmp3))
    last_res[s]=tmp1

# %%
#첫번쨰방법 리스트와 enu활용하기 
sear=['gold','silver','platinum']

last_res={}
for idx,t in enumerate(tot9):
    tmp1=[]
    for j in t:
        tmp3=[]
        for i in j.find_all('div','tabulator-row'):
            tmp2=[]
            for k in i:
                k.find_all('div','tabulator-cell')
                tmp2.append(k.text)
            tmp3.append(tmp2)
        tmp1.append(pd.DataFrame(tmp3))
    last_res[sear[idx]]=tmp1

# %%
#첫번쨰방법 리스트와 enu활용하기 
sear=['gold','silver','platinum']

last_res=[]
for idx,t in enumerate(tot9):
    tmp1=[]
    for j in t:
        tmp3=[]
        for i in j.find_all('div','tabulator-row'):
            tmp2=[]
            for k in i:
                k.find_all('div','tabulator-cell')
                tmp2.append(k.text)
            tmp3.append(tmp2)
        tmp1.append(pd.DataFrame(tmp3))
    last_res.append(tmp1)

# %%
last_res[2]
# Out:
# [             0        1        2
#  0   2023.02.03  171,000  143,000
#  1   2023.02.02  169,000  141,000
#  2   2023.02.01  169,000  141,000
#  3   2023.01.31  169,000  141,000
#  4   2023.01.30  170,000  142,000
#  5   2023.01.28  170,000  142,000
#  6   2023.01.27  171,000  142,000
#  7   2023.01.26  175,000  146,000
#  8   2023.01.25  177,000  148,000
#  9   2023.01.24  176,000  147,000
#  10  2023.01.21  175,000  146,000
#  11  2023.01.20  173,000  145,000
#  12  2023.01.19  175,000  146,000
#  13  2023.01.18  175,000  146,000
#  14  2023.01.17  179,000  149,000,
#               0        1        2
#  0   2023.01.16  180,000  150,000
#  1   2023.01.14  181,000  151,000
#  2   2023.01.13  182,000  151,000
#  3   2023.01.12  182,000  152,000
#  4   2023.01.11  183,000  153,000
#  5   2023.01.10  182,000  153,000
#  6   2023.01.09  186,000  156,000
#  7   2023.01.07  189,000  158,000
#  8   2023.01.06  183,000  153,000
#  9   2023.01.05  186,000  155,000
# ...

# %%
numbers = ['one', 'two', 'three', 'four', 'five']
   
for n in numbers:
    print(n)
# Out:
# one
# two
# three
# four
# five

# %%
sear[0]
# Out:
# 'gold'

# %%
enumerate(sear)

# %%
sear[0]
for i in enumerate
# Out:
#   Cell In[47], line 2
#     for i in enumerate
#                       ^
# SyntaxError: expected ':'

# %%
last_res
# Out:
# [[             0        1        2        3        4
#   0   2023.02.03  326,000  294,000  211,700  163,200
#   1   2023.02.02  331,000  295,000  212,400  163,800
#   2   2023.02.01  328,000  295,000  212,400  163,800
#   3   2023.01.31  327,000  295,000  212,400  163,800
#   4   2023.01.30  327,500  295,000  212,400  163,800
#   5   2023.01.28  329,000  295,000  212,400  163,800
#   6   2023.01.27  328,000  295,000  212,400  163,800
#   7   2023.01.26  331,000  296,000  213,200  164,300
#   8   2023.01.25  329,000  296,000  213,200  164,300
#   9   2023.01.24  330,000  295,000  212,400  163,800
#   10  2023.01.21  329,000  295,000  212,400  163,800
#   11  2023.01.20  329,000  295,000  212,400  163,800
#   12  2023.01.19  326,000  294,000  211,700  163,200
#   13  2023.01.18  326,000  294,000  211,700  163,200
#   14  2023.01.17  327,000  295,000  212,400  163,800,
#                0        1        2        3        4
#   0   2023.01.16  328,500  296,000  213,200  164,300
# ...

# %%
#------------------------------
sear=['gold','silver','platinum']

last_res={}
for s,t in zip(sear,tot9):
    tmp1=[]
    for j in t:
        tmp3=[]
        for i in j.find_all('div','tabulator-row'):
            tmp2=[]
            for k in i:
                k.find_all('div','tabulator-cell')
                tmp2.append(k.text)
            tmp3.append(tmp2)
        tmp1.append(pd.DataFrame(tmp3))
    last_res[s]=tmp1

# %%
res_df=pd.concat(last_res['gold'])
res_df.columns=['날짜','살때 순금','팔때 순금','18k','14k']
res_df1=res_df.reset_index()      #리셋인덱스 적용
res_df2=res_df1.drop(res_df1.columns[0],axis=1)  #인덱스 삭제 
res_df2
# Out:
#             날짜    살때 순금    팔때 순금      18k      14k
# 0   2023.02.03  326,000  294,000  211,700  163,200
# 1   2023.02.02  331,000  295,000  212,400  163,800
# 2   2023.02.01  328,000  295,000  212,400  163,800
# 3   2023.01.31  327,000  295,000  212,400  163,800
# 4   2023.01.30  327,500  295,000  212,400  163,800
# ..         ...      ...      ...      ...      ...
# 74  2022.11.08  320,500  290,000  208,800  161,000
# 75  2022.11.07  324,500  292,000  210,300  162,100
# 76  2022.11.05  329,000  291,000  209,600  161,600
# 77  2022.11.04  323,000  290,000  208,800  161,000
# 78  2022.11.03  323,000  291,000  209,600  161,600
#
# [79 rows x 5 columns]

# %%
last_res
# Out:
# {'gold': [             0        1        2        3        4
#   0   2023.02.03  326,000  294,000  211,700  163,200
#   1   2023.02.02  331,000  295,000  212,400  163,800
#   2   2023.02.01  328,000  295,000  212,400  163,800
#   3   2023.01.31  327,000  295,000  212,400  163,800
#   4   2023.01.30  327,500  295,000  212,400  163,800
#   5   2023.01.28  329,000  295,000  212,400  163,800
#   6   2023.01.27  328,000  295,000  212,400  163,800
#   7   2023.01.26  331,000  296,000  213,200  164,300
#   8   2023.01.25  329,000  296,000  213,200  164,300
#   9   2023.01.24  330,000  295,000  212,400  163,800
#   10  2023.01.21  329,000  295,000  212,400  163,800
#   11  2023.01.20  329,000  295,000  212,400  163,800
#   12  2023.01.19  326,000  294,000  211,700  163,200
#   13  2023.01.18  326,000  294,000  211,700  163,200
#   14  2023.01.17  327,000  295,000  212,400  163,800,
#                0        1        2        3        4
#   0   2023.01.16  328,500  296,000  213,200  164,300
# ...

# %%
last_res.keys()
# Out:
# dict_keys(['gold', 'silver', 'platinum'])

# %%
last_res['silver']
# Out:
# [             0      1      2
#  0   2023.02.03  4,100  3,110
#  1   2023.02.02  4,170  3,180
#  2   2023.02.01  4,120  3,140
#  3   2023.01.31  4,100  3,120
#  4   2023.01.30  4,120  3,130
#  5   2023.01.28  4,130  3,140
#  6   2023.01.27  4,160  3,170
#  7   2023.01.26  4,160  3,170
#  8   2023.01.25  4,120  3,130
#  9   2023.01.24  4,110  3,120
#  10  2023.01.21  4,170  3,190
#  11  2023.01.20  4,160  3,170
#  12  2023.01.19  4,120  3,120
#  13  2023.01.18  4,190  3,190
#  14  2023.01.17  4,220  3,220,
#               0      1      2
#  0   2023.01.16  4,250  3,240
#  1   2023.01.14  4,250  3,250
#  2   2023.01.13  4,170  3,180
#  3   2023.01.12  4,130  3,140
#  4   2023.01.11  4,170  3,170
#  5   2023.01.10  4,170  3,160
#  6   2023.01.09  4,230  3,230
#  7   2023.01.07  4,280  3,270
#  8   2023.01.06  4,190  3,180
#  9   2023.01.05  4,290  3,260
#  10  2023.01.04  4,370  3,330
#  11  2023.01.03  4,400  3,370
#  12  2023.01.02  4,330  3,300
#  13  2022.12.31  4,300  3,270
# ...

# %%
last_res[2]
# Out:
# [             0        1        2
#  0   2023.02.03  171,000  143,000
#  1   2023.02.02  169,000  141,000
#  2   2023.02.01  169,000  141,000
#  3   2023.01.31  169,000  141,000
#  4   2023.01.30  170,000  142,000
#  5   2023.01.28  170,000  142,000
#  6   2023.01.27  171,000  142,000
#  7   2023.01.26  175,000  146,000
#  8   2023.01.25  177,000  148,000
#  9   2023.01.24  176,000  147,000
#  10  2023.01.21  175,000  146,000
#  11  2023.01.20  173,000  145,000
#  12  2023.01.19  175,000  146,000
#  13  2023.01.18  175,000  146,000
#  14  2023.01.17  179,000  149,000,
#               0        1        2
#  0   2023.01.16  180,000  150,000
#  1   2023.01.14  181,000  151,000
#  2   2023.01.13  182,000  151,000
#  3   2023.01.12  182,000  152,000
#  4   2023.01.11  183,000  153,000
#  5   2023.01.10  182,000  153,000
#  6   2023.01.09  186,000  156,000
#  7   2023.01.07  189,000  158,000
#  8   2023.01.06  183,000  153,000
#  9   2023.01.05  186,000  155,000
# ...

# %%
#금값 크롤링 

sear=['gold','silver','platinum']


res_gold=[]
for j in tot9[0]:
    tmp3=[]
    for i in j.find_all('div','tabulator-row'):
        tmp2=[]
        for k in i:
            k.find_all('div','tabulator-cell')
            tmp2.append(k.text)
        tmp3.append(tmp2)
    res_gold.append(pd.DataFrame(tmp3))

# %%
#은값 크롤링 
res_silver=[]
for j in tot9[1]:
    tmp3=[]
    for i in j.find_all('div','tabulator-row'):
        tmp2=[]
        for k in i:
            k.find_all('div','tabulator-cell')
            tmp2.append(k.text)
        tmp3.append(tmp2)
    res_silver.append(pd.DataFrame(tmp3))

# %%
#백금값 크롤링 
res_p=[]
for j in tot9[2]:
    tmp3=[]
    for i in j.find_all('div','tabulator-row'):
        tmp2=[]
        for k in i:
            k.find_all('div','tabulator-cell')
            tmp2.append(k.text)
        tmp3.append(tmp2)
    res_p.append(pd.DataFrame(tmp3))

# %%
# sear=['gold','silver','platinum']
# for i in sear:
#     url=f'https://www.koreagoldx.co.kr/main/html.php?agencyCode=&htmid=goods/{i}_list.html'
#     print(url)

# %%
res_df=pd.concat(res_gold)
res_df.columns=['날짜','살때 순금','팔때 순금','18k','14k']
res_df1=res_df.reset_index()      #리셋인덱스 적용
res_df2=res_df1.drop(res_df1.columns[0],axis=1)  #인덱스 삭제 
res_df2
# Out:
#             날짜    살때 순금    팔때 순금      18k      14k
# 0   2023.02.03  326,000  294,000  211,700  163,200
# 1   2023.02.02  331,000  295,000  212,400  163,800
# 2   2023.02.01  328,000  295,000  212,400  163,800
# 3   2023.01.31  327,000  295,000  212,400  163,800
# 4   2023.01.30  327,500  295,000  212,400  163,800
# ..         ...      ...      ...      ...      ...
# 74  2022.11.08  320,500  290,000  208,800  161,000
# 75  2022.11.07  324,500  292,000  210,300  162,100
# 76  2022.11.05  329,000  291,000  209,600  161,600
# 77  2022.11.04  323,000  290,000  208,800  161,000
# 78  2022.11.03  323,000  291,000  209,600  161,600
#
# [79 rows x 5 columns]

# %%
pd.to_datetime(res_df2['날짜'])
res_df2['날짜']=pd.to_datetime(res_df2['날짜'])
res_df2['요일'] = res_df2['날짜'].dt.day_name()
res_df2['월'] = res_df2['날짜'].dt.month
res_df2['년도'] = res_df2['날짜'].dt.year

res_df2['살때 순금']=pd.to_numeric(res_df2['살때 순금'].str.replace(',',''))
res_df2['팔때 순금']=pd.to_numeric(res_df2['팔때 순금'].str.replace(',',''))
res_df2['18k']=pd.to_numeric(res_df2['18k'].str.replace(',',''))
res_df2['14k']=pd.to_numeric(res_df2['14k'].str.replace(',',''))
res_df2['살때,팔때 차이']=res_df2['살때 순금']-res_df2['팔때 순금']
res_df2['18k-14k']=res_df2['18k']-res_df2['14k']

# %%
for i in res_df2.iloc[]:
    i

# %%
res_df2.iloc[:,1:]=pd.to_numeric(res_df2.iloc[:,1:].str.replace(',',''))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 res_df2.iloc[:,1:]=pd.to_numeric(res_df2.iloc[:,1:].str.replace(',',''))
#
# File ~\.conda\envs\han\lib\site-packages\pandas\core\generic.py:5902, in NDFrame.__getattr__(self, name)
#    5895 if (
#    5896     name not in self._internal_names_set
#    5897     and name not in self._metadata
#    5898     and name not in self._accessors
#    5899     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5900 ):
#    5901     return self[name]
# -> 5902 return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'str'

# %%
#은값 크롤링 
res_silver=[]
for j in tot9[1]:
    tmp3=[]
    for i in j.find_all('div','tabulator-row'):
        tmp2=[]
        for k in i:
            k.find_all('div','tabulator-cell')
            tmp2.append(k.text)
        tmp3.append(tmp2)
    res_silver.append(pd.DataFrame(tmp3))

# %%
pd.concat(res_silver)
# Out:
#              0      1      2
# 0   2023.02.03  4,100  3,110
# 1   2023.02.02  4,170  3,180
# 2   2023.02.01  4,120  3,140
# 3   2023.01.31  4,100  3,120
# 4   2023.01.30  4,120  3,130
# ..         ...    ...    ...
# 14  2022.11.08  4,050  3,220
# 0   2022.11.07  4,100  3,240
# 1   2022.11.05  4,170  3,300
# 2   2022.11.04  3,970  3,220
# 3   2022.11.03  3,880  3,140
#
# [79 rows x 3 columns]

# %%
pd.to_datetime(res_df2['날짜'])
# Out:
# 0    2023-02-02
# 1    2023-02-01
# 2    2023-01-31
# 3    2023-01-30
# 4    2023-01-28
#         ...
# 73   2022-11-08
# 74   2022-11-07
# 75   2022-11-05
# 76   2022-11-04
# 77   2022-11-03
# Name: 날짜, Length: 78, dtype: datetime64[ns]

# %%
res_df2['날짜']=pd.to_datetime(res_df2['날짜'])

# %%
res_df2
# Out:
#            날짜    살때 순금    팔때 순금      18k      14k
# 0  2023-02-02  331,000  295,000  212,400  163,800
# 1  2023-02-01  328,000  295,000  212,400  163,800
# 2  2023-01-31  327,000  295,000  212,400  163,800
# 3  2023-01-30  327,500  295,000  212,400  163,800
# 4  2023-01-28  329,000  295,000  212,400  163,800
# ..        ...      ...      ...      ...      ...
# 73 2022-11-08  320,500  290,000  208,800  161,000
# 74 2022-11-07  324,500  292,000  210,300  162,100
# 75 2022-11-05  329,000  291,000  209,600  161,600
# 76 2022-11-04  323,000  290,000  208,800  161,000
# 77 2022-11-03  323,000  291,000  209,600  161,600
#
# [78 rows x 5 columns]

# %%
res_df2['요일'] = res_df2['날짜'].dt.day_name()

res_df2
# Out:
#            날짜    살때 순금    팔때 순금      18k      14k         요일
# 0  2023-02-02  331,000  295,000  212,400  163,800   Thursday
# 1  2023-02-01  328,000  295,000  212,400  163,800  Wednesday
# 2  2023-01-31  327,000  295,000  212,400  163,800    Tuesday
# 3  2023-01-30  327,500  295,000  212,400  163,800     Monday
# 4  2023-01-28  329,000  295,000  212,400  163,800   Saturday
# ..        ...      ...      ...      ...      ...        ...
# 73 2022-11-08  320,500  290,000  208,800  161,000    Tuesday
# 74 2022-11-07  324,500  292,000  210,300  162,100     Monday
# 75 2022-11-05  329,000  291,000  209,600  161,600   Saturday
# 76 2022-11-04  323,000  290,000  208,800  161,000     Friday
# 77 2022-11-03  323,000  291,000  209,600  161,600   Thursday
#
# [78 rows x 6 columns]

# %%
res_df2['살때 순금']=pd.to_numeric(res_df2['살때 순금'].str.replace(',',''))
res_df2['팔때 순금']=pd.to_numeric(res_df2['팔때 순금'].str.replace(',',''))
res_df2['18k']=pd.to_numeric(res_df2['18k'].str.replace(',',''))
res_df2['14k']=pd.to_numeric(res_df2['14k'].str.replace(',',''))

# %%
res_df2['살때,팔때 차이']=res_df2['살때 순금']-res_df2['팔때 순금']
res_df2
# Out:
#            날짜   살때 순금   팔때 순금     18k     14k         요일  살때,팔때 차이
# 0  2023-02-02  331000  295000  212400  163800   Thursday     36000
# 1  2023-02-01  328000  295000  212400  163800  Wednesday     33000
# 2  2023-01-31  327000  295000  212400  163800    Tuesday     32000
# 3  2023-01-30  327500  295000  212400  163800     Monday     32500
# 4  2023-01-28  329000  295000  212400  163800   Saturday     34000
# ..        ...     ...     ...     ...     ...        ...       ...
# 73 2022-11-08  320500  290000  208800  161000    Tuesday     30500
# 74 2022-11-07  324500  292000  210300  162100     Monday     32500
# 75 2022-11-05  329000  291000  209600  161600   Saturday     38000
# 76 2022-11-04  323000  290000  208800  161000     Friday     33000
# 77 2022-11-03  323000  291000  209600  161600   Thursday     32000
#
# [78 rows x 7 columns]

# %%
res_df2
# Out:
#            날짜   살때 순금   팔때 순금     18k     14k         요일  살때,팔때 차이
# 0  2023-02-02  331000  295000  212400  163800   Thursday     36000
# 1  2023-02-01  328000  295000  212400  163800  Wednesday     33000
# 2  2023-01-31  327000  295000  212400  163800    Tuesday     32000
# 3  2023-01-30  327500  295000  212400  163800     Monday     32500
# 4  2023-01-28  329000  295000  212400  163800   Saturday     34000
# ..        ...     ...     ...     ...     ...        ...       ...
# 73 2022-11-08  320500  290000  208800  161000    Tuesday     30500
# 74 2022-11-07  324500  292000  210300  162100     Monday     32500
# 75 2022-11-05  329000  291000  209600  161600   Saturday     38000
# 76 2022-11-04  323000  290000  208800  161000     Friday     33000
# 77 2022-11-03  323000  291000  209600  161600   Thursday     32000
#
# [78 rows x 7 columns]

# %%
res_df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 78 entries, 0 to 77
# Data columns (total 7 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   날짜        78 non-null     datetime64[ns]
#  1   살때 순금     78 non-null     int64
#  2   팔때 순금     78 non-null     int64
#  3   18k       78 non-null     int64
#  4   14k       78 non-null     int64
#  5   요일        78 non-null     object
#  6   살때,팔때 차이  78 non-null     int64
# dtypes: datetime64[ns](1), int64(5), object(1)
# memory usage: 4.4+ KB

# %%
res_df2.groupby('요일').min()
# Out:
#                   날짜   살때 순금   팔때 순금     18k     14k  살때,팔때 차이
# 요일
# Friday    2022-11-04  318500  285000  205200  158200     30000
# Monday    2022-11-07  318500  286000  206000  158800     31000
# Saturday  2022-11-05  319500  285000  205200  158200     32000
# Thursday  2022-11-03  317500  285000  205200  158200     28000
# Tuesday   2022-11-08  319000  285500  205600  158500     28500
# Wednesday 2022-11-09  319000  286000  206000  158800     28500

# %%
res_df2.set_index('요일')
# Out:
#                   날짜   살때 순금   팔때 순금     18k     14k  살때,팔때 차이
# 요일
# Thursday  2023-02-02  331000  295000  212400  163800     36000
# Wednesday 2023-02-01  328000  295000  212400  163800     33000
# Tuesday   2023-01-31  327000  295000  212400  163800     32000
# Monday    2023-01-30  327500  295000  212400  163800     32500
# Saturday  2023-01-28  329000  295000  212400  163800     34000
# ...              ...     ...     ...     ...     ...       ...
# Tuesday   2022-11-08  320500  290000  208800  161000     30500
# Monday    2022-11-07  324500  292000  210300  162100     32500
# Saturday  2022-11-05  329000  291000  209600  161600     38000
# Friday    2022-11-04  323000  290000  208800  161000     33000
# Thursday  2022-11-03  323000  291000  209600  161600     32000
#
# [78 rows x 6 columns]

# %%
res_df2['날짜'][0]
# Out:
# Timestamp('2023-02-02 00:00:00')

# %%
for i in res_df2['날짜']:
    print(i[1:4])
    break
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[19], line 2
#       1 for i in res_df2['날짜']:
# ----> 2     print(i[1:4])
#       3     break
#
# TypeError: 'Timestamp' object is not subscriptable

# %%
res_df2['월'] = res_df2['날짜'].dt.month

# %%
res_df2
# Out:
#            날짜   살때 순금   팔때 순금     18k     14k         요일  살때,팔때 차이   월
# 0  2023-02-02  331000  295000  212400  163800   Thursday     36000   2
# 1  2023-02-01  328000  295000  212400  163800  Wednesday     33000   2
# 2  2023-01-31  327000  295000  212400  163800    Tuesday     32000   1
# 3  2023-01-30  327500  295000  212400  163800     Monday     32500   1
# 4  2023-01-28  329000  295000  212400  163800   Saturday     34000   1
# ..        ...     ...     ...     ...     ...        ...       ...  ..
# 73 2022-11-08  320500  290000  208800  161000    Tuesday     30500  11
# 74 2022-11-07  324500  292000  210300  162100     Monday     32500  11
# 75 2022-11-05  329000  291000  209600  161600   Saturday     38000  11
# 76 2022-11-04  323000  290000  208800  161000     Friday     33000  11
# 77 2022-11-03  323000  291000  209600  161600   Thursday     32000  11
#
# [78 rows x 8 columns]

# %%
res_df2['18k-14k']=res_df2['18k']-res_df2['14k']
res_df2
# Out:
#            날짜   살때 순금   팔때 순금     18k     14k         요일  살때,팔때 차이   월  \
# 0  2023-02-02  331000  295000  212400  163800   Thursday     36000   2
# 1  2023-02-01  328000  295000  212400  163800  Wednesday     33000   2
# 2  2023-01-31  327000  295000  212400  163800    Tuesday     32000   1
# 3  2023-01-30  327500  295000  212400  163800     Monday     32500   1
# 4  2023-01-28  329000  295000  212400  163800   Saturday     34000   1
# ..        ...     ...     ...     ...     ...        ...       ...  ..
# 73 2022-11-08  320500  290000  208800  161000    Tuesday     30500  11
# 74 2022-11-07  324500  292000  210300  162100     Monday     32500  11
# 75 2022-11-05  329000  291000  209600  161600   Saturday     38000  11
# 76 2022-11-04  323000  290000  208800  161000     Friday     33000  11
# 77 2022-11-03  323000  291000  209600  161600   Thursday     32000  11
#
#     18k-14k
# 0     48600
# 1     48600
# 2     48600
# 3     48600
# 4     48600
# ..      ...
# 73    47800
# ...

# %%
res_df2['년도'] = res_df2['날짜'].dt.year
res_df2
# Out:
#            날짜   살때 순금   팔때 순금     18k     14k         요일  살때,팔때 차이   월  \
# 0  2023-02-02  331000  295000  212400  163800   Thursday     36000   2
# 1  2023-02-01  328000  295000  212400  163800  Wednesday     33000   2
# 2  2023-01-31  327000  295000  212400  163800    Tuesday     32000   1
# 3  2023-01-30  327500  295000  212400  163800     Monday     32500   1
# 4  2023-01-28  329000  295000  212400  163800   Saturday     34000   1
# ..        ...     ...     ...     ...     ...        ...       ...  ..
# 73 2022-11-08  320500  290000  208800  161000    Tuesday     30500  11
# 74 2022-11-07  324500  292000  210300  162100     Monday     32500  11
# 75 2022-11-05  329000  291000  209600  161600   Saturday     38000  11
# 76 2022-11-04  323000  290000  208800  161000     Friday     33000  11
# 77 2022-11-03  323000  291000  209600  161600   Thursday     32000  11
#
#     18k-14k    년도
# 0     48600  2023
# 1     48600  2023
# 2     48600  2023
# 3     48600  2023
# ...

# %%
#월을 벨류카운트를 해보기

# %%
res_df2['월'].value_counts()
# Out:
# 12    27
# 1     25
# 11    24
# 2      2
# Name: 월, dtype: int64

# %%
res_df2['월'].value_counts().plot(kind='bar')
# Out:
# <AxesSubplot: >

# %%
res_df2.groupby('월').mean()['18k']
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_20664\3596822089.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   res_df2.groupby('월').mean()['18k']
# 월
# 1     211732.000000
# 2     212400.000000
# 11    208945.833333
# 12    206203.703704
# Name: 18k, dtype: float64

# %%
res_df2.groupby('월').mean()['18k']
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_20664\3596822089.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   res_df2.groupby('월').mean()['18k']
# 월
# 1     211732.000000
# 2     212400.000000
# 11    208945.833333
# 12    206203.703704
# Name: 18k, dtype: float64

# %%
res_df2.groupby('월').mean()[res_df2.columns[1]]
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_20664\1592719656.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   res_df2.groupby('월').mean()[res_df2.columns[1]]
# 월
# 1     326660.000000
# 2     329500.000000
# 11    324083.333333
# 12    322018.518519
# Name: 살때 순금, dtype: float64

# %%
tot=[]
for i in range(1,5):
    a=res_df2.groupby('월').mean()[res_df2.columns[i]]
    tot.append(pd.DataFrame(a))
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_20664\3808947157.py:3: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   a=res_df2.groupby('월').mean()[res_df2.columns[i]]
# C:\Users\user\AppData\Local\Temp\ipykernel_20664\3808947157.py:3: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   a=res_df2.groupby('월').mean()[res_df2.columns[i]]
# ...

# %%
tot=[]
for i in range(1,5):
    a=res_df2.groupby('월').mean()[res_df2.columns[i]]
    tot.append(pd.DataFrame(a))

# %%
res_df2
# Out:
#             날짜    살때 순금    팔때 순금      18k      14k
# 0   2023.02.03  326,000  294,000  211,700  163,200
# 1   2023.02.02  331,000  295,000  212,400  163,800
# 2   2023.02.01  328,000  295,000  212,400  163,800
# 3   2023.01.31  327,000  295,000  212,400  163,800
# 4   2023.01.30  327,500  295,000  212,400  163,800
# ..         ...      ...      ...      ...      ...
# 74  2022.11.08  320,500  290,000  208,800  161,000
# 75  2022.11.07  324,500  292,000  210,300  162,100
# 76  2022.11.05  329,000  291,000  209,600  161,600
# 77  2022.11.04  323,000  290,000  208,800  161,000
# 78  2022.11.03  323,000  291,000  209,600  161,600
#
# [79 rows x 5 columns]

# %%
res_df2['날짜']
# Out:
# 0     2023.02.03
# 1     2023.02.02
# 2     2023.02.01
# 3     2023.01.31
# 4     2023.01.30
#          ...
# 74    2022.11.08
# 75    2022.11.07
# 76    2022.11.05
# 77    2022.11.04
# 78    2022.11.03
# Name: 날짜, Length: 79, dtype: object

# %%
tot1
# Out:
#             살때 순금          팔때 순금            18k            14k
# 월
# 1   326660.000000            NaN            NaN            NaN
# 2   329500.000000            NaN            NaN            NaN
# 11  324083.333333            NaN            NaN            NaN
# 12  322018.518519            NaN            NaN            NaN
# 1             NaN  294020.000000            NaN            NaN
# 2             NaN  295000.000000            NaN            NaN
# 11            NaN  290145.833333            NaN            NaN
# 12            NaN  286333.333333            NaN            NaN
# 1             NaN            NaN  211732.000000            NaN
# 2             NaN            NaN  212400.000000            NaN
# 11            NaN            NaN  208945.833333            NaN
# 12            NaN            NaN  206203.703704            NaN
# 1             NaN            NaN            NaN  163236.000000
# 2             NaN            NaN            NaN  163800.000000
# ...

# %%
tot1.isnull
# Out:
# <bound method DataFrame.isnull of             살때 순금          팔때 순금            18k            14k
# 월
# 1   326660.000000            NaN            NaN            NaN
# 2   329500.000000            NaN            NaN            NaN
# 11  324083.333333            NaN            NaN            NaN
# 12  322018.518519            NaN            NaN            NaN
# 1             NaN  294020.000000            NaN            NaN
# 2             NaN  295000.000000            NaN            NaN
# 11            NaN  290145.833333            NaN            NaN
# 12            NaN  286333.333333            NaN            NaN
# 1             NaN            NaN  211732.000000            NaN
# 2             NaN            NaN  212400.000000            NaN
# 11            NaN            NaN  208945.833333            NaN
# 12            NaN            NaN  206203.703704            NaN
# 1             NaN            NaN            NaN  163236.000000
# ...

# %%
tot1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 16 entries, 1 to 12
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   살때 순금   4 non-null      float64
#  1   팔때 순금   4 non-null      float64
#  2   18k     4 non-null      float64
#  3   14k     4 non-null      float64
# dtypes: float64(4)
# memory usage: 640.0 bytes

# %%
tot1.isnull().sum()
# Out:
# 살때 순금    12
# 팔때 순금    12
# 18k      12
# 14k      12
# dtype: int64

# %%
tot1=pd.concat(tot)

# %%
tot1
# Out:
#             살때 순금          팔때 순금            18k            14k
# 월
# 1   326660.000000            NaN            NaN            NaN
# 2   329500.000000            NaN            NaN            NaN
# 11  324083.333333            NaN            NaN            NaN
# 12  322018.518519            NaN            NaN            NaN
# 1             NaN  294020.000000            NaN            NaN
# 2             NaN  295000.000000            NaN            NaN
# 11            NaN  290145.833333            NaN            NaN
# 12            NaN  286333.333333            NaN            NaN
# 1             NaN            NaN  211732.000000            NaN
# 2             NaN            NaN  212400.000000            NaN
# 11            NaN            NaN  208945.833333            NaN
# 12            NaN            NaN  206203.703704            NaN
# 1             NaN            NaN            NaN  163236.000000
# 2             NaN            NaN            NaN  163800.000000
# ...

# %%
tot1
# Out:
#             살때 순금          팔때 순금            18k            14k
# 월
# 1   326660.000000            NaN            NaN            NaN
# 2   329500.000000            NaN            NaN            NaN
# 11  324083.333333            NaN            NaN            NaN
# 12  322018.518519            NaN            NaN            NaN
# 1             NaN  294020.000000            NaN            NaN
# 2             NaN  295000.000000            NaN            NaN
# 11            NaN  290145.833333            NaN            NaN
# 12            NaN  286333.333333            NaN            NaN
# 1             NaN            NaN  211732.000000            NaN
# 2             NaN            NaN  212400.000000            NaN
# 11            NaN            NaN  208945.833333            NaN
# 12            NaN            NaN  206203.703704            NaN
# 1             NaN            NaN            NaN  163236.000000
# 2             NaN            NaN            NaN  163800.000000
# ...

# %%
tot1.iloc[:4,:1]
# Out:
#             살때 순금
# 월
# 1   326660.000000
# 2   329500.000000
# 11  324083.333333
# 12  322018.518519

# %%
tot1.iloc[4:8,1:2]
# Out:
#             팔때 순금
# 월
# 1   294020.000000
# 2   295000.000000
# 11  290145.833333
# 12  286333.333333

# %%
tot1.iloc[8:12,2:3]
# Out:
#               18k
# 월
# 1   211732.000000
# 2   212400.000000
# 11  208945.833333
# 12  206203.703704

# %%
tot1.iloc[12:16,3:4]
# Out:
#               14k
# 월
# 1   163236.000000
# 2   163800.000000
# 11  161091.666667
# 12  158966.666667

# %%
tot2=[]
for i in range(1,5):
    k=tot1.iloc[(i-1)*4:i*4,i-1:i]
    tot2.append(pd.DataFrame(k))

# %%
tot2[0]
# Out:
#             살때 순금
# 월
# 1   326660.000000
# 2   329500.000000
# 11  324083.333333
# 12  322018.518519

# %%
a=pd.merge(tot2[0],tot2[1],on='월')
a
# Out:
#             살때 순금          팔때 순금
# 월
# 1   326660.000000  294020.000000
# 2   329500.000000  295000.000000
# 11  324083.333333  290145.833333
# 12  322018.518519  286333.333333

# %%
b=pd.merge(tot2[2],tot2[3],on='월')
b
# Out:
#               18k            14k
# 월
# 1   211732.000000  163236.000000
# 2   212400.000000  163800.000000
# 11  208945.833333  161091.666667
# 12  206203.703704  158966.666667

# %%
tot3=pd.merge(a,b,on='월')
tot3
#이것은 월별 평균가격들
# Out:
#             살때 순금          팔때 순금            18k            14k
# 월
# 1   326660.000000  294020.000000  211732.000000  163236.000000
# 2   329500.000000  295000.000000  212400.000000  163800.000000
# 11  324083.333333  290145.833333  208945.833333  161091.666667
# 12  322018.518519  286333.333333  206203.703704  158966.666667

# %%
tot2=[]
for i in range(1,5):
    k=tot1.iloc[(i-1)*4:i*4,i-1:i]
    tot2.append(pd.DataFrame(k))

# %%
pd.concat(tot2)
# Out:
#             살때 순금          팔때 순금            18k            14k
# 월
# 1   326660.000000            NaN            NaN            NaN
# 2   329500.000000            NaN            NaN            NaN
# 11  324083.333333            NaN            NaN            NaN
# 12  322018.518519            NaN            NaN            NaN
# 1             NaN  294020.000000            NaN            NaN
# 2             NaN  295000.000000            NaN            NaN
# 11            NaN  290145.833333            NaN            NaN
# 12            NaN  286333.333333            NaN            NaN
# 1             NaN            NaN  211732.000000            NaN
# 2             NaN            NaN  212400.000000            NaN
# 11            NaN            NaN  208945.833333            NaN
# 12            NaN            NaN  206203.703704            NaN
# 1             NaN            NaN            NaN  163236.000000
# 2             NaN            NaN            NaN  163800.000000
# ...

# %%
pd.concat(tot).isnull()
# Out:
#     살때 순금  팔때 순금    18k    14k
# 월
# 1   False   True   True   True
# 2   False   True   True   True
# 11  False   True   True   True
# 12  False   True   True   True
# 1    True  False   True   True
# 2    True  False   True   True
# 11   True  False   True   True
# 12   True  False   True   True
# 1    True   True  False   True
# 2    True   True  False   True
# 11   True   True  False   True
# 12   True   True  False   True
# 1    True   True   True  False
# 2    True   True   True  False
# 11   True   True   True  False
# 12   True   True   True  False

# %%
res_df2.groupby('요일').mean()
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_20664\3197999335.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   res_df2.groupby('요일').mean()
#                    살때 순금          팔때 순금            18k            14k  \
# 요일
# Friday     323461.538462  290115.384615  208930.769231  161061.538462
# Monday     324250.000000  289791.666667  208691.666667  160891.666667
# Saturday   325423.076923  290115.384615  208923.076923  161069.230769
# Thursday   324535.714286  290571.428571  209250.000000  161321.428571
# Tuesday    323884.615385  290038.461538  208861.538462  161038.461538
# Wednesday  324423.076923  290461.538462  209169.230769  161261.538462
#
#                살때,팔때 차이         월       18k-14k
# 요일
# Friday     33346.153846  8.307692  47869.230769
# ...

# %%
#데이터 정제를 어캐해야할지.. 그룹바이 활용을 어캐해야하는지 
res_df2.groupby('요일').mean()[['18k']]
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_20664\63086807.py:2: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   res_df2.groupby('요일').mean()[['18k']]
#                      18k
# 요일
# Friday     208930.769231
# Monday     208691.666667
# Saturday   208923.076923
# Thursday   209250.000000
# Tuesday    208861.538462
# Wednesday  209169.230769

# %%
res_df2.groupby('월').mean()['18k']
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_20664\3596822089.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   res_df2.groupby('월').mean()['18k']
# 월
# 1     211732.000000
# 2     212400.000000
# 11    208945.833333
# 12    206203.703704
# Name: 18k, dtype: float64

# %%
res_df2.groupby('월').mean()['팔때 순금']
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_20664\2201200232.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   res_df2.groupby('월').mean()['팔때 순금']
# 월
# 1     294020.000000
# 2     295000.000000
# 11    290145.833333
# 12    286333.333333
# Name: 팔때 순금, dtype: float64

# %%
res_df2.set_index('요일')
# Out:
#                   날짜   살때 순금   팔때 순금     18k     14k  살때,팔때 차이   월  18k-14k
# 요일
# Thursday  2023-02-02  331000  295000  212400  163800     36000   2    48600
# Wednesday 2023-02-01  328000  295000  212400  163800     33000   2    48600
# Tuesday   2023-01-31  327000  295000  212400  163800     32000   1    48600
# Monday    2023-01-30  327500  295000  212400  163800     32500   1    48600
# Saturday  2023-01-28  329000  295000  212400  163800     34000   1    48600
# ...              ...     ...     ...     ...     ...       ...  ..      ...
# Tuesday   2022-11-08  320500  290000  208800  161000     30500  11    47800
# Monday    2022-11-07  324500  292000  210300  162100     32500  11    48200
# Saturday  2022-11-05  329000  291000  209600  161600     38000  11    48000
# Friday    2022-11-04  323000  290000  208800  161000     33000  11    47800
# Thursday  2022-11-03  323000  291000  209600  161600     32000  11    48000
#
# [78 rows x 8 columns]

# %%
res_df2.iloc[:,:1]
# Out:
#            날짜
# 0  2023-02-02
# 1  2023-02-01
# 2  2023-01-31
# 3  2023-01-30
# 4  2023-01-28
# ..        ...
# 74 2022-11-07
# 75 2022-11-05
# 76 2022-11-04
# 77 2022-11-03
# 78 2022-11-02
#
# [79 rows x 1 columns]

# %%
# 0~6번 인덱스 위치에 각 한글 요일 이름이 담긴 리스트
weekday_list = ['월', '화', '수', '목', '금', '토', '일']

# apply 함수로 숫자 -> 요일 이름으로 변환
res_df2['요일'] = res_df2.apply(lambda x : weekday_list[x['weekd']], axis = 1)

res_df2
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[40], line 5
#       2 weekday_list = ['월', '화', '수', '목', '금', '토', '일']
#       4 # apply 함수로 숫자 -> 요일 이름으로 변환
# ----> 5 res_df2['요일'] = res_df2.apply(lambda x : weekday_list[x['날짜']], axis = 1)
#       7 res_df2
#
# File ~\.conda\envs\han\lib\site-packages\pandas\core\frame.py:9565, in DataFrame.apply(self, func, axis, raw, result_type, args, **kwargs)
#    9554 from pandas.core.apply import frame_apply
#    9556 op = frame_apply(
#    9557     self,
#    9558     func=func,
#    (...)
#    9563     kwargs=kwargs,
#    9564 )
# -> 9565 return op.apply().__finalize__(self, method="apply")
#
# File ~\.conda\envs\han\lib\site-packages\pandas\core\apply.py:746, in FrameApply.apply(self)
#     743 elif self.raw:
#     744     return self.apply_raw()
# --> 746 return self.apply_standard()
#
# ...

# %%
import matplotlib.pyplot as plt


res_df['살때 순금']=pd.to_numeric(res_df['살때 순금'].str.replace(',',''))

# %%
res_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 79 entries, 0 to 3
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   날짜      79 non-null     object
#  1   살때 순금   79 non-null     int64
#  2   팔때 순금   79 non-null     object
#  3   18k     79 non-null     object
#  4   14k     79 non-null     object
# dtypes: int64(1), object(4)
# memory usage: 3.7+ KB

# %%
buygold=res_df.set_index('날짜').iloc[:,:1]
buygold
# Out:
#              살때 순금
# 날짜
# 2023.02.02  329000
# 2023.02.01  328000
# 2023.01.31  327000
# 2023.01.30  327500
# 2023.01.28  329000
# ...            ...
# 2022.11.07  324500
# 2022.11.05  329000
# 2022.11.04  323000
# 2022.11.03  323000
# 2022.11.02  323500
#
# [79 rows x 1 columns]

# %%
plt.figure(figsize=(50,30))
buygold.plot(kind='bar');
# Out:
# C:\Users\user\.conda\envs\han\lib\site-packages\IPython\core\events.py:89: UserWarning: Glyph 45216 (\N{HANGUL SYLLABLE NAL}) missing from current font.
#   func(*args, **kwargs)
# C:\Users\user\.conda\envs\han\lib\site-packages\IPython\core\events.py:89: UserWarning: Glyph 51676 (\N{HANGUL SYLLABLE JJA}) missing from current font.
#   func(*args, **kwargs)
# C:\Users\user\.conda\envs\han\lib\site-packages\IPython\core\events.py:89: UserWarning: Glyph 49332 (\N{HANGUL SYLLABLE SAL}) missing from current font.
#   func(*args, **kwargs)
# C:\Users\user\.conda\envs\han\lib\site-packages\IPython\core\events.py:89: UserWarning: Glyph 46412 (\N{HANGUL SYLLABLE DDAE}) missing from current font.
#   func(*args, **kwargs)
# C:\Users\user\.conda\envs\han\lib\site-packages\IPython\core\events.py:89: UserWarning: Glyph 49692 (\N{HANGUL SYLLABLE SUN}) missing from current font.
#   func(*args, **kwargs)
# ...

# %%
from IPython.display import Image

# seaborn
import seaborn as sns


res_df['살때 순금'].value_counts().plot(kind='bar')
plt.show()
res_df['팔때 순금'].value_counts().plot(kind='bar')
plt.show()
3res_df['18k'].value_counts().plot(kind='bar')
# Out:
# <AxesSubplot: >

# %%
#----------------------------------------------

# %%
res_df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 78 entries, 0 to 77
# Data columns (total 9 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   날짜        78 non-null     datetime64[ns]
#  1   살때 순금     78 non-null     int64
#  2   팔때 순금     78 non-null     int64
#  3   18k       78 non-null     int64
#  4   14k       78 non-null     int64
#  5   요일        78 non-null     object
#  6   살때,팔때 차이  78 non-null     int64
#  7   월         78 non-null     int64
#  8   18k-14k   78 non-null     int64
# dtypes: datetime64[ns](1), int64(7), object(1)
# memory usage: 5.6+ KB

# %%
res_df2.
# Out:
#            날짜   살때 순금   팔때 순금     18k     14k         요일  살때,팔때 차이   월  \
# 0  2023-02-02  331000  295000  212400  163800   Thursday     36000   2
# 1  2023-02-01  328000  295000  212400  163800  Wednesday     33000   2
# 2  2023-01-31  327000  295000  212400  163800    Tuesday     32000   1
# 3  2023-01-30  327500  295000  212400  163800     Monday     32500   1
# 4  2023-01-28  329000  295000  212400  163800   Saturday     34000   1
# ..        ...     ...     ...     ...     ...        ...       ...  ..
# 73 2022-11-08  320500  290000  208800  161000    Tuesday     30500  11
# 74 2022-11-07  324500  292000  210300  162100     Monday     32500  11
# 75 2022-11-05  329000  291000  209600  161600   Saturday     38000  11
# 76 2022-11-04  323000  290000  208800  161000     Friday     33000  11
# 77 2022-11-03  323000  291000  209600  161600   Thursday     32000  11
#
#     18k-14k
# 0     48600
# 1     48600
# 2     48600
# 3     48600
# 4     48600
# ..      ...
# 73    47800
# ...

# %%
res_df2.describe()
# Out:
#                살때 순금          팔때 순금            18k            14k  \
# count      78.000000      78.000000      78.000000      78.000000
# mean   324333.333333  290192.307692  208978.205128  161112.820513
# std      3108.081910    3589.514645    2581.585511    1993.258702
# min    317500.000000  285000.000000  205200.000000  158200.000000
# 25%    322500.000000  287000.000000  206700.000000  159300.000000
# 50%    324000.000000  290000.000000  208800.000000  161000.000000
# 75%    326500.000000  293375.000000  211300.000000  162850.000000
# max    331000.000000  296000.000000  213200.000000  164300.000000
#
#            살때,팔때 차이          월       18k-14k
# count     78.000000  78.000000     78.000000
# mean   34141.025641   7.910256  47865.384615
# std     2492.713324   5.025095    590.141282
# min    28000.000000   1.000000  47000.000000
# 25%    32500.000000   1.000000  47400.000000
# 50%    34000.000000  11.000000  47800.000000
# 75%    36000.000000  12.000000  48450.000000
# ...

# %%
res_df2.groupby('월').mean()
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_20664\352700867.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   res_df2.groupby('월').mean()
#             살때 순금          팔때 순금            18k            14k      살때,팔때 차이  \
# 월
# 1   326660.000000  294020.000000  211732.000000  163236.000000  32640.000000
# 2   329500.000000  295000.000000  212400.000000  163800.000000  34500.000000
# 11  324083.333333  290145.833333  208945.833333  161091.666667  33937.500000
# 12  322018.518519  286333.333333  206203.703704  158966.666667  35685.185185
#
#          18k-14k
# 월
# 1   48496.000000
# 2   48600.000000
# 11  47854.166667
# 12  47237.037037

# %%
tott4=round(res_df2.groupby('월').mean())
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_20664\3286367629.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   tott4=round(res_df2.groupby('월').mean())

# %%
#박스플롯 활용하기 
ㅠ

# %%
import matplotlib.pyplot as plt
import numpy as np

plt.style.use('default')
plt.rcParams['figure.figsize'] = (4, 3)
plt.rcParams['font.size'] = 12

# 2. 데이터 준비
np.random.seed(0)
data_a = np.random.normal(0, 2.0, 1000)
data_b = np.random.normal(-3.0, 1.5, 500)
data_c = np.random.normal(1.2, 1.5, 1500)

# 3. 그래프 그리기
fig, ax = plt.subplots()

ax.boxplot([data_a, data_b, data_c])
ax.set_ylim(-10.0, 10.0)
ax.set_xlabel('Data Type')
ax.set_ylabel('Value')

plt.show()

# %%
plt.boxplot(a)
plt.tight_layout()
plt.show()

# %%
a
# Out:
#        살때 순금     팔때 순금       18k       14k  살때,팔때 차이  18k-14k      년도
# 월
# 1   326660.0  294020.0  211732.0  163236.0   32640.0  48496.0  2023.0
# 2   329500.0  295000.0  212400.0  163800.0   34500.0  48600.0  2023.0
# 11  324083.0  290146.0  208946.0  161092.0   33938.0  47854.0  2022.0
# 12  322019.0  286333.0  206204.0  158967.0   35685.0  47237.0  2022.0

# %%
b=a.drop('년도',axis=1)
b
# Out:
#        살때 순금     팔때 순금       18k       14k  살때,팔때 차이  18k-14k
# 월
# 1   326660.0  294020.0  211732.0  163236.0   32640.0  48496.0
# 2   329500.0  295000.0  212400.0  163800.0   34500.0  48600.0
# 11  324083.0  290146.0  208946.0  161092.0   33938.0  47854.0
# 12  322019.0  286333.0  206204.0  158967.0   35685.0  47237.0

# %%
res_df2
# Out:
#            날짜   살때 순금   팔때 순금     18k     14k         요일  살때,팔때 차이   월  \
# 0  2023-02-02  331000  295000  212400  163800   Thursday     36000   2
# 1  2023-02-01  328000  295000  212400  163800  Wednesday     33000   2
# 2  2023-01-31  327000  295000  212400  163800    Tuesday     32000   1
# 3  2023-01-30  327500  295000  212400  163800     Monday     32500   1
# 4  2023-01-28  329000  295000  212400  163800   Saturday     34000   1
# ..        ...     ...     ...     ...     ...        ...       ...  ..
# 73 2022-11-08  320500  290000  208800  161000    Tuesday     30500  11
# 74 2022-11-07  324500  292000  210300  162100     Monday     32500  11
# 75 2022-11-05  329000  291000  209600  161600   Saturday     38000  11
# 76 2022-11-04  323000  290000  208800  161000     Friday     33000  11
# 77 2022-11-03  323000  291000  209600  161600   Thursday     32000  11
#
#     18k-14k    년도
# 0     48600  2023
# 1     48600  2023
# 2     48600  2023
# 3     48600  2023
# ...

# %%
plt.boxplot(res_df2)
plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[192], line 1
# ----> 1 plt.boxplot(res_df2)
#       2 plt.tight_layout()
#       3 plt.show()
#
# File ~\.conda\envs\han\lib\site-packages\matplotlib\pyplot.py:2411, in boxplot(x, notch, sym, vert, whis, positions, widths, patch_artist, bootstrap, usermedians, conf_intervals, meanline, showmeans, showcaps, showbox, showfliers, boxprops, labels, flierprops, medianprops, meanprops, capprops, whiskerprops, manage_ticks, autorange, zorder, capwidths, data)
#    2401 @_copy_docstring_and_deprecators(Axes.boxplot)
#    2402 def boxplot(
#    2403         x, notch=None, sym=None, vert=None, whis=None,
#    (...)
#    2409         whiskerprops=None, manage_ticks=True, autorange=False,
#    2410         zorder=None, capwidths=None, *, data=None):
# -> 2411     return gca().boxplot(
# ...

# %%
res_sns=res_df2.drop('날짜',axis=1)

# %%
import seaborn as sns
sns.boxplot(x='살때,팔때 차이',data=res_sns)
plt.show()
# Out:
# C:\Users\user\.conda\envs\han\lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 49332 (\N{HANGUL SYLLABLE SAL}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\user\.conda\envs\han\lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 46412 (\N{HANGUL SYLLABLE DDAE}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\user\.conda\envs\han\lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 54036 (\N{HANGUL SYLLABLE PAL}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\user\.conda\envs\han\lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 52264 (\N{HANGUL SYLLABLE CA}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# C:\Users\user\.conda\envs\han\lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Glyph 51060 (\N{HANGUL SYLLABLE I}) missing from current font.
# ...

# %%
res_sns
# Out:
#      살때 순금   팔때 순금     18k     14k         요일  살때,팔때 차이   월  18k-14k    년도
# 0   331000  295000  212400  163800   Thursday     36000   2    48600  2023
# 1   328000  295000  212400  163800  Wednesday     33000   2    48600  2023
# 2   327000  295000  212400  163800    Tuesday     32000   1    48600  2023
# 3   327500  295000  212400  163800     Monday     32500   1    48600  2023
# 4   329000  295000  212400  163800   Saturday     34000   1    48600  2023
# ..     ...     ...     ...     ...        ...       ...  ..      ...   ...
# 73  320500  290000  208800  161000    Tuesday     30500  11    47800  2022
# 74  324500  292000  210300  162100     Monday     32500  11    48200  2022
# 75  329000  291000  209600  161600   Saturday     38000  11    48000  2022
# 76  323000  290000  208800  161000     Friday     33000  11    47800  2022
# 77  323000  291000  209600  161600   Thursday     32000  11    48000  2022
#
# [78 rows x 9 columns]

# %%
sns.lmplot(x='살때 순금',y='팔때 순금',data=res_sns,hue='월')
# Out:
# C:\Users\user\.conda\envs\han\lib\site-packages\seaborn\axisgrid.py:118: UserWarning: Glyph 49332 (\N{HANGUL SYLLABLE SAL}) missing from current font.
#   self._figure.tight_layout(*args, **kwargs)
# C:\Users\user\.conda\envs\han\lib\site-packages\seaborn\axisgrid.py:118: UserWarning: Glyph 46412 (\N{HANGUL SYLLABLE DDAE}) missing from current font.
#   self._figure.tight_layout(*args, **kwargs)
# C:\Users\user\.conda\envs\han\lib\site-packages\seaborn\axisgrid.py:118: UserWarning: Glyph 49692 (\N{HANGUL SYLLABLE SUN}) missing from current font.
#   self._figure.tight_layout(*args, **kwargs)
# C:\Users\user\.conda\envs\han\lib\site-packages\seaborn\axisgrid.py:118: UserWarning: Glyph 44552 (\N{HANGUL SYLLABLE GEUM}) missing from current font.
#   self._figure.tight_layout(*args, **kwargs)
# C:\Users\user\.conda\envs\han\lib\site-packages\seaborn\axisgrid.py:118: UserWarning: Glyph 54036 (\N{HANGUL SYLLABLE PAL}) missing from current font.
# ...

# %%
plt.figure(figsize=(7,5))

y = res_df2['18k']
x = res_df2['날짜']

plt.plot(x, y)

plt.xlabel('날짜', fontsize=15)
plt.ylabel('18k값', fontsize=15)
plt.title('18k값 추이', fontsize=18)

plt.show()

# %%
plt.figure(figsize=(7,5))

y = res_df2['18k']
x = res_df2['날짜']
y_2=res_df2['14k']

plt.plot(x, y, label='18k',color='blue', alpha=0.3 )
plt.plot(x,y_2,label='14k',color='red', alpha=0.7)

plt.xlabel('날짜', fontsize=15)
plt.ylabel('1값', fontsize=15)
plt.title('18k, 14k값 추이', fontsize=18)

plt.legend()
plt.show()

# %%
plt.figure(figsize=(7,5))

y = res_df2['18k']
x = res_df2['년도']
y_2=res_df2['14k']

plt.plot(x, y, label='18k',color='blue', alpha=0.3 )
plt.plot(x,y_2,label='14k',color='red', alpha=0.7)

plt.xlabel('년도', fontsize=15)
plt.ylabel('1값', fontsize=15)
plt.title('18k, 14k값 추이', fontsize=18)

plt.legend()
plt.show()

# %%
plt.figure(figsize=(7,5))

y = res_df2['18k']
x = res_df2['날짜']
y_2=res_df2['14k']
y_3=res_df2['살때 순금']
y_4=res_df2['팔때 순금']




plt.plot(x, y, label='18k',color='blue', alpha=0.3 )
plt.plot(x,y_2,label='14k',color='red', alpha=0.7)
plt.plot(x,y_3,label='살때 순금',color='black', alpha=0.4)
plt.plot(x,y_4,label='팔때 순금',color='yellow', alpha=0.7)


plt.xlabel('날짜', fontsize=15)
plt.ylabel('값', fontsize=15)
plt.title('값 추이', fontsize=18)

plt.legend()
plt.show()

# %%
plt.boxplot(res_df2['18k'])
plt.tight_layout()
plt.show()

# %%
tott4
# Out:
#        살때 순금     팔때 순금       18k       14k  살때,팔때 차이  18k-14k      년도
# 월
# 1   326660.0  294020.0  211732.0  163236.0   32640.0  48496.0  2023.0
# 2   329500.0  295000.0  212400.0  163800.0   34500.0  48600.0  2023.0
# 11  324083.0  290146.0  208946.0  161092.0   33938.0  47854.0  2022.0
# 12  322019.0  286333.0  206204.0  158967.0   35685.0  47237.0  2022.0

# %%
x = np.arange(0, 10, 0.1)
y_1 = 1 + np.sin(x)
y_2 = 1 + np.cos(x)

plt.plot(x, y_1, label='1+sin', color='blue', alpha=0.3)
plt.plot(x, y_2, label='1+cos', color='red', alpha=0.7)

plt.xlabel('x value', fontsize=15)
plt.ylabel('y value', fontsize=15)
plt.title('sin and cos graph', fontsize=18)

plt.grid()
plt.legend()

plt.show()

# %%
N = 100000
bins = 30

x = res_df2

plt.hist(x, bins=bins)

plt.show()

# %%
b
# Out:
#        살때 순금     팔때 순금       18k       14k  살때,팔때 차이  18k-14k
# 월
# 1   326660.0  294020.0  211732.0  163236.0   32640.0  48496.0
# 2   329500.0  295000.0  212400.0  163800.0   34500.0  48600.0
# 11  324083.0  290146.0  208946.0  161092.0   33938.0  47854.0
# 12  322019.0  286333.0  206204.0  158967.0   35685.0  47237.0
